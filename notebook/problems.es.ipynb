# %% [markdown]
# # Problemas de prueba de hipótesis

# %% [markdown]
# ## Ejercicio 1
#
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?
#
# Para sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd

# %%
# TODO
diet1 = [2,2.5,3,2.8,2.3,2.7,2.5]
diet2 = [3,3.2,3.1,2.9,2.8,3,3.2]
alpha = 0.05
# Null Hipothesis: There's no significant difference between the average of weight lost in both groups "H0 : μ1 = μ2"
# Alternative Hipothesis: There is a significant difference between the average of weight lost from one group to the other one "H1 : μ1 != μ2"

#Calculo p_value para testeo de hipotesis luego
p_value = stats.ttest_ind(diet1,diet2).pvalue
print(p_value)

if p_value<alpha :
    print('The Null Hypothesis is rejected.')
    print("There's evidence of a significant difference between two groups' weight loss")
else : print("There's NO evidence of a significant difference between two groups' weight loss")
# Out:
# 0.004083270191713912
# The Null Hypothesis is rejected.
# There's evidence of a significant difference between two groups' weight loss

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## Ejercicio 2
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %%
# TODO
fertilizer_1 = [20,21,20,19,20,19,20]
fertilizer_2 = [22,21,23,22,21,22,21]
fertilizer_3 = [24,23,22,23,24,23,24]

alpha = 0.05
# Null Hipothesis, H0: There's no significant difference between the average corn yields in the 3 different types of fertilizers VER ESTO "H0 : μ1 = μ2"
# Alternative Hipothesis, H1: There is at least 1 significant difference between the average corn yields within the 3 different types of fertilizers VER ESTO "H1 : μ1 != μ2"

#ANOVA
p_value_2 = stats.f_oneway(fertilizer_1,fertilizer_2,fertilizer_3).pvalue #recomended for using ANOVA
print(f'P-Value: {p_value_2}')

if p_value_2 < alpha :
    print('The Null Hypothesis is rejected.')
    print("There is at least 1 significant difference between the average corn yields within the 3 different types of fertilizers")
else : print("There's NO evidence of a significant difference between the average corn yields within the 3 different types of fertilizers")

# Better Fertilizer
f1_mean, f1_std, f1_length = np.mean(fertilizer_1), np.std(fertilizer_1), len(fertilizer_1) #get the mean and std for each fertilizer, and lenght of data
f2_mean, f2_std, f2_length = np.mean(fertilizer_2), np.std(fertilizer_2), len(fertilizer_2)
f3_mean, f3_std, f3_length = np.mean(fertilizer_3), np.std(fertilizer_3), len(fertilizer_3)

# determind the confidence intervals
def confidence_interval(data_mean, data_std, data_lenght, confidence= 0.95):
    std_err = data_std / np.sqrt(data_lenght) 
    h = std_err * stats.t.ppf((1 + confidence) / 2., data_lenght-1)
    return data_mean, data_mean - h, data_mean + h

f1_conf_int = confidence_interval(f1_mean, f1_std, f1_length)
f2_conf_int = confidence_interval(f2_mean, f2_std, f2_length)
f3_conf_int = confidence_interval(f3_mean, f3_std, f3_length)

df_comparison = pd.DataFrame(columns=['Mean','Mean - error margin', 'Mean + error margin'], data=[f1_conf_int, f2_conf_int, f3_conf_int],index=['fertilizer_1','fertilizer_2','fertilizer_3'])
df_comparison
# Out:
# P-Value: 3.3282620087563596e-07
# The Null Hypothesis is rejected.
# There is at least 1 significant difference between the average corn yields within the 3 different types of fertilizers
#                    Mean  Mean - error margin  Mean + error margin
# fertilizer_1  19.857143            19.266281            20.448005
# fertilizer_2  21.714286            21.067029            22.361543
# fertilizer_3  23.285714            22.638457            23.932971
